# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\\User\\jupyter-noutbooks\\05-Seaborn\\StudentsPerformance.csv')

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
sns.boxplot(x='parental level of education',y='math score',data=df)
# Out:
# <AxesSubplot:xlabel='parental level of education', ylabel='math score'>

# %%
sns.violinplot(y='gender',x='reading score',data=df)
# Out:
# <AxesSubplot:xlabel='reading score', ylabel='gender'>

# %%
plt.figure(figsize=(12,8))
sns.swarmplot(x='writing score',y='race/ethnicity',data=df)
# Out:
# <AxesSubplot:xlabel='writing score', ylabel='race/ethnicity'>

# %%
sns.jointplot(data=df,x='math score',y='reading score',kind='hex')

# %%
sns.jointplot(data=df,x='math score',y='reading score',hue='gender')

# %%
sns.pairplot(data=df[['reading score','writing score']])

# %%
sns.catplot(data=df,x='gender',y='math score',kind='box'
           ,col='lunch',row='test preparation course')

# %%
sns.pairplot(data=df)

# %%
g = sns.PairGrid(df)

g = g.map_upper(sns.scatterplot)

g = g.map_diag(sns.histplot)

g = g.map_lower(sns.kdeplot)
